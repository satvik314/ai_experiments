# %% [markdown]
# <a href="https://colab.research.google.com/github/satvik314/ai_experiments/blob/main/AudioModels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Audio Models

# %% [markdown]
# Try it in playground: https://elevenlabs.io/

# %% [markdown]
# ## text2speech

# %% [markdown]
# ### Installation

# %%
# !pip install -qU elevenlabs langchain langchain-openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.4/246.4 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00

# %%
from elevenlabs import generate, play, set_api_key

# set_api_key("")

# %% [markdown]
# ### Convert text to voice

# %%
audio = generate(
    text = "Type whatever want",
    voice = "Adam"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = generate(
    text = "Type whatever want",
    voice = "Adam"
)

play(audio, notebook = True)

# %%
# changed voice

audio = generate(
    text = "Welcome to Crash Course on Generative AI by Build Fast with AI.",
    voice = "Rachel"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Getting responses in Hindi

# %%
audio = generate(
    text = "व्याख्यान में आपका स्वागत है!",
    voice = "Rachel",
    model = "eleven_multilingual_v2"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# using Multilingual Model
#

audio = generate(
    text = "सभी को नमस्कार, आशा है कि आप कुछ नया सीख रहे होंगे।",
    voice = "Satvik",
    model = "eleven_multilingual_v2"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = generate(
    text = "మీరు ఆస్వాదిస్తున్నారని ఆశిస్తున్నాను",
    voice = "Rachel",
    model = "eleven_multilingual_v2"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os

os.environ['OPENAI_API_KEY'] = "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"

# %% [markdown]
# ### Voice Chat with LLM

# %%
from langchain_openai import ChatOpenAI

# to be able to use LLM to generate text for the audio
llm = ChatOpenAI()

# %%
response = llm.invoke("How do volcanoes work?")
print(response.content)
# Out:
# Volcanoes are formed when molten rock (magma) deep within the Earth's crust rises to the surface. This can happen due to the movement of tectonic plates, which cause the Earth's crust to crack and allow magma to escape.
#
# When the magma reaches the surface, it erupts in the form of lava, ash, and gases. This can result in explosive eruptions, where magma is violently expelled from the volcano, or effusive eruptions, where lava flows steadily from the volcano.
#
# Volcanoes are typically located along tectonic plate boundaries, such as the Ring of Fire in the Pacific Ocean, where the Earth's crust is most active. They can also be found in hotspots, where magma rises up through the Earth's mantle.
#
# The eruption of a volcano can have devastating consequences, including the destruction of nearby communities, the release of toxic gases, and the formation of lahars (mudflows) and pyroclastic flows. However, volcanoes also play a vital role in the Earth's ecosystem by releasing nutrients into the soil and creating new landforms.

# %%
def get_reply_in_voice(text):
  response = llm.invoke(text)
  audio = generate(
                      text = response.content,
                      voice = "Rachel"
                  )
  play(audio, notebook = True)

# %%
get_reply_in_voice("Who was the first Nobel prize winner?")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_multilingual_reply(text):
  response = llm.invoke(text)
  audio = generate(
    text = response.content,
    voice = "Rachel",
    model = "eleven_multilingual_v2"
)

  play(audio, notebook = True)

# %%
get_multilingual_reply("आप कैसे हैं?")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
get_multilingual_reply("మీరు ఎలా ఉన్నారు?")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## speech2text

# %% [markdown]
# ### Transcriptions using Whisper Model

# %%
# !pip install -qU openai

# %%
from openai import OpenAI
client = OpenAI()

# %%
audio_file = open("/content/GenAI_Intro_Audio.mp3", "rb")
transcript = client.audio.transcriptions.create(
  model="whisper-1",
  file=audio_file,
  response_format="text"
)

print(transcript)


# try uploading Hindi audio?
# Out:
# Step into the futuristic world of generative AI with our comprehensive 4-week course. This program is meticulously crafted to provide you with firm grounding in generative AI technologies, empowering you to build innovative applications that can transform industries. With a blend of theoretical knowledge and hands-on experience, embark on a journey to becoming a proficient AI developer.

# %% [markdown]
# ### Meeting Summariser

# %%
# Summarise the meeting

def summarise_meeting(meeting_audio):
  audio_file = open(meeting_audio, "rb")
  transcript = client.audio.transcriptions.create(
                        model="whisper-1",
                        file=audio_file,
                        response_format="text"
                      )

  llm = ChatOpenAI(model = "gpt-3.5-turbo")
  result = llm.invoke(f""" Summarise the below transcript into 3 bullet points
                  {transcript}
  """)

  return result.content

# %%
print(summarise_meeting("/content/GenAI_Intro_Audio.mp3"))
# Out:
# - 4-week course on generative AI
# - Focus on providing firm grounding in generative AI technologies
# - Blend of theoretical knowledge and hands-on experience to become a proficient AI developer

# %%
print(summarise_meeting("/content/How to get motivated even when you dont feel like it.mp3"))
# Out:
# - Motivation is defined as the desire or impetus to initiate and maintain a particular behavior, and can fall into two broad categories: intrinsic and extrinsic.
# - Intrinsic motivation involves doing an activity for its own sake, while extrinsic motivation involves pursuing a task as a means to an end, such as receiving a reward.
# - High levels of intrinsic motivation are more likely to keep you engaged in the long run, while having multiple motivators can sometimes decrease overall motivation levels.
