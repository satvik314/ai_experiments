# %% [markdown]
# <a href="https://colab.research.google.com/github/satvik314/ai_experiments/blob/main/ft_autotrain_mistral_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fine-tuning Mistral 7b with AutoTrain

# %% [markdown]
# Setup Runtime
# For fine-tuning Llama, a GPU instance is essential. Follow the directions below:
#
# - Go to `Runtime` (located in the top menu bar).
# - Select `Change Runtime Type`.
# - Choose `T4 GPU` (or a comparable option).

# %% [markdown]
# ### Step 1: Setup Environment

# %%
# !pip install pandas autotrain-advanced -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 54.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 44.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 113.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 118.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 76.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 92.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 96.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 97.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 98.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 34.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 97.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 25.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 101.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 113.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.9/99.9 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.9 MB/s eta 0:00:00
#   Building wheel for ipadic (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.

# %%
# !autotrain setup --update-torch
# Out:
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %% [markdown]
# ## Step 2: Connect to HuggingFace for Model Upload
#
# ### Logging to Hugging Face
# To make sure the model can be uploaded to be used for Inference, it's necessary to log in to the Hugging Face hub.
#
# ### Getting a Hugging Face token
# Steps:
#
# 1. Navigate to this URL: https://huggingface.co/settings/tokens
# 2. Create a write `token` and copy it to your clipboard
# 3. Run the code below and enter your `token`

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8d90e1ab2248> in <cell line: 1>()
# ----> 1 from huggingface_hub import notebook_login
#       2 notebook_login()
#
# ModuleNotFoundError: No module named 'huggingface_hub'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Step 3: Upload your dataset
#
# Add your data set to the root directory in the Colab under the name train.csv. The AutoTrain command will look for your data there under that name.
#
# #### Don't have a data set and want to try finetuning on an example data set?
# If you don't have a dataset you can run these commands below to get an example data set and save it to train.csv

# %%
# !git clone https://github.com/joshbickett/finetune-llama-2.git
# %cd finetune-llama-2
# %mv train.csv ../train.csv
# %cd ..
# Out:
# Cloning into 'finetune-llama-2'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 70 (delta 38), reused 48 (delta 19), pack-reused 0
# Receiving objects: 100% (70/70), 25.13 KiB | 5.03 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/finetune-llama-2
# /content

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#                                     Concept  \
# 0                 A cactus at a dance party
# 1                   A robot on a first date
# 2                A snail at a speed contest
# 3                A penguin at a beach party
# 4                     A cloud in a bad mood
# ..                                      ...
# 112      A donut feeling the hole emptiness
# 113     A pineapple with a prickly attitude
# 114  A calculator crunching life's problems
# 115             A kite reaching new heights
# 116            A teddy bear feeling stuffed
#
#                               Funny Description Prompt  \
# 0    A cactus, wearing disco lights and surrounded ...
# 1    A robot, with a bouquet of USB cables, nervous...
# 2    A snail, with a mini rocket booster, confident...
# 3    A penguin, with sunscreen and a surfboard, try...
# 4    A cloud, grumbling and dropping mini lightning...
# ..                                                 ...
# 112  A donut, in existential bakery therapy, ponder...
# 113  A pineapple, in a prickly personality class, s...
# 114  A calculator, at a problem-solving workshop, c...
# 115  A kite, in an altitude adjustment session, unt...
# 116  A teddy bear, in a fluff mindfulness group, em...
#
#                                                   text
# 0    ###Human:\nGenerate a midjourney prompt for A ...
# 1    ###Human:\nGenerate a midjourney prompt for A ...
# 2    ###Human:\nGenerate a midjourney prompt for A ...
# 3    ###Human:\nGenerate a midjourney prompt for A ...
# 4    ###Human:\nGenerate a midjourney prompt for A ...
# ..                                                 ...
# 112  ###Human:\nGenerate a midjourney prompt for A ...
# 113  ###Human:\nGenerate a midjourney prompt for A ...
# 114  ###Human:\nGenerate a midjourney prompt for A ...
# 115  ###Human:\nGenerate a midjourney prompt for A ...
# 116  ###Human:\nGenerate a midjourney prompt for A ...
#
# [117 rows x 3 columns]

# %%
df['text'][15]
# Out:
# '###Human:\ngenerate a midjourney prompt for A turtle sunbathing on a rock\n\n###Assistant:\nA turtle with sunglasses on, sunbathing on a rock, with a mini fan and a drink beside it.'

# %% [markdown]
# ## Step 4: Overview of AutoTrain command
#
# #### Short overview of what the command flags do.
#
# - `!autotrain`: Command executed in environments like a Jupyter notebook to run shell commands directly. `autotrain` is an automatic training utility.
#
# - `llm`: A sub-command or argument specifying the type of task
#
# - `--train`: Initiates the training process.
#
# - `--project_name`: Sets the name of the project
#
# - `--model abhishek/llama-2-7b-hf-small-shards`: Specifies original model that is hosted on Hugging Face named "llama-2-7b-hf-small-shards" under the "abhishek".
#
# - `--data_path .`: The path to the dataset for training. The "." refers to the current directory. The `train.csv` file needs to be located in this directory.
#
# - `--use_int4`: Use of INT4 quantization to reduce model size and speed up inference times at the cost of some precision.
#
# - `--learning_rate 2e-4`: Sets the learning rate for training to 0.0002.
#
# - `--train_batch_size 12`: Sets the batch size for training to 12.
#
# - `--num_train_epochs 3`: The training process will iterate over the dataset 3 times.
#
# ### Steps needed before running
# Go to the `!autotrain` code cell below and update it by following the steps below:
#
# 1. After `--project_name` replace `*enter-a-project-name*` with the name that you'd like to call the project
# 2. After `--repo_id` replace `*username*/*repository*`. Replace `*username*` with your Hugging Face username and `*repository*` with the repository name you'd like it to be created under. You don't need to create this repository before hand, it will automatically be created and uploaded once the training is completed.
# 3. Confirm that `train.csv` is in the root directory in the Colab. The `--data_path .` flag will make it so that AutoTrain looks for your data there.
# 4. Make sure to add the LoRA Target Modules to be trained `--target-modules q_proj, v_proj`
# 5. Once you've made these changes you're all set, run the command below!

# %%
# !autotrain llm --train --project_name mistral-7b-mj-finetuned2 --model bn22/Mistral-7B-Instruct-v0.1-sharded --data_path . --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 12 --num_train_epochs 3 --trainer sft --target_modules q_proj,v_proj --push_to_hub --repo_id satvikp/mistral-7b-mj-finetuned2 --token "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"
# Out:
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, train=True, deploy=False, inference=False, data_path='.', train_split='train', valid_split=None, text_column='text', rejected_text_column='rejected', prompt_text_column='prompt', model='bn22/Mistral-7B-Instruct-v0.1-sharded', model_ref=None, learning_rate=0.0002, num_train_epochs=3, train_batch_size=12, warmup_ratio=0.1, gradient_accumulation_steps=1, optimizer='adamw_torch', scheduler='linear', weight_decay=0.0, max_grad_norm=1.0, seed=42, add_eos_token=False, block_size=-1, use_peft=True, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, project_name='mistral-7b-mj-finetuned2', evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, fp16=False, push_to_hub=True, use_int8=False, model_max_length=1024, repo_id='satvikp/mistral-7b-mj-finetuned2', use_int4=True, trainer='sft', target_modules='q_proj,v_proj', merge_adapter=False, token='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', backend='default', username=None, use_flash_attention_2=False, log='none', disable_gradient_checkpointing=False, dpo_beta=0.1, func=<function run_llm_command_factory at 0x795910af4790>)
# > INFO    loading dataset from csv
# Downloading (…)okenizer_config.json: 100% 963/963 [00:00<00:00, 4.55MB/s]
# Downloading tokenizer.model: 100% 493k/493k [00:00<00:00, 14.3MB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.80M/1.80M [00:00<00:00, 5.41MB/s]
# Downloading (…)cial_tokens_map.json: 100% 72.0/72.0 [00:00<00:00, 371kB/s]
# Downloading (…)lve/main/config.json: 100% 571/571 [00:00<00:00, 3.44MB/s]
# Downloading (…)model.bin.index.json: 100% 23.9k/23.9k [00:00<00:00, 75.5MB/s]
# Downloading shards:   0% 0/11 [00:00<?, ?it/s]
# Downloading (…)l_00001-of-00010.bin:   0% 0.00/1.54G [00:00<?, ?B/s]
# Downloading (…)l_00001-of-00010.bin:   1% 10.5M/1.54G [00:00<00:15, 100MB/s]
# Downloading (…)l_00001-of-00010.bin:   3% 41.9M/1.54G [00:00<00:07, 207MB/s]
# Downloading (…)l_00001-of-00010.bin:   6% 94.4M/1.54G [00:00<00:04, 316MB/s]
# Downloading (…)l_00001-of-00010.bin:  10% 147M/1.54G [00:00<00:03, 367MB/s]
# Downloading (…)l_00001-of-00010.bin:  13% 199M/1.54G [00:00<00:03, 400MB/s]
# Downloading (…)l_00001-of-00010.bin:  16% 252M/1.54G [00:00<00:03, 425MB/s]
# Downloading (…)l_00001-of-00010.bin:  20% 304M/1.54G [00:00<00:02, 440MB/s]
# Downloading (…)l_00001-of-00010.bin:  23% 357M/1.54G [00:00<00:02, 451MB/s]
# Downloading (…)l_00001-of-00010.bin:  26% 409M/1.54G [00:01<00:02, 456MB/s]
# Downloading (…)l_00001-of-00010.bin:  30% 461M/1.54G [00:01<00:02, 460MB/s]
# Downloading (…)l_00001-of-00010.bin:  33% 514M/1.54G [00:01<00:02, 463MB/s]
# Downloading (…)l_00001-of-00010.bin:  37% 566M/1.54G [00:01<00:02, 461MB/s]
# Downloading (…)l_00001-of-00010.bin:  40% 619M/1.54G [00:01<00:02, 457MB/s]
# Downloading (…)l_00001-of-00010.bin:  43% 671M/1.54G [00:01<00:01, 451MB/s]
# Downloading (…)l_00001-of-00010.bin:  47% 724M/1.54G [00:01<00:01, 447MB/s]
# Downloading (…)l_00001-of-00010.bin:  50% 776M/1.54G [00:01<00:01, 422MB/s]
# Downloading (…)l_00001-of-00010.bin:  54% 828M/1.54G [00:02<00:01, 395MB/s]
# Downloading (…)l_00001-of-00010.bin:  56% 870M/1.54G [00:02<00:01, 388MB/s]
# Downloading (…)l_00001-of-00010.bin:  59% 912M/1.54G [00:02<00:01, 380MB/s]
# Downloading (…)l_00001-of-00010.bin:  62% 954M/1.54G [00:02<00:01, 389MB/s]
# Downloading (…)l_00001-of-00010.bin:  65% 1.01G/1.54G [00:02<00:01, 404MB/s]
# Downloading (…)l_00001-of-00010.bin:  69% 1.06G/1.54G [00:02<00:01, 415MB/s]
# Downloading (…)l_00001-of-00010.bin:  72% 1.11G/1.54G [00:02<00:01, 421MB/s]
# Downloading (…)l_00001-of-00010.bin:  75% 1.16G/1.54G [00:03<00:01, 227MB/s]
# Downloading (…)l_00001-of-00010.bin:  78% 1.21G/1.54G [00:03<00:01, 228MB/s]
# Downloading (…)l_00001-of-00010.bin:  81% 1.25G/1.54G [00:03<00:01, 254MB/s]
# Downloading (…)l_00001-of-00010.bin:  84% 1.29G/1.54G [00:03<00:00, 255MB/s]
# Downloading (…)l_00001-of-00010.bin:  86% 1.32G/1.54G [00:03<00:00, 252MB/s]
# Downloading (…)l_00001-of-00010.bin:  88% 1.35G/1.54G [00:03<00:00, 247MB/s]
# Downloading (…)l_00001-of-00010.bin:  90% 1.38G/1.54G [00:04<00:00, 227MB/s]
# Downloading (…)l_00001-of-00010.bin:  92% 1.42G/1.54G [00:04<00:00, 208MB/s]
# Downloading (…)l_00001-of-00010.bin:  94% 1.45G/1.54G [00:04<00:00, 184MB/s]
# Downloading (…)l_00001-of-00010.bin:  95% 1.47G/1.54G [00:04<00:00, 168MB/s]
# Downloading (…)l_00001-of-00010.bin:  96% 1.49G/1.54G [00:04<00:00, 162MB/s]
# Downloading (…)l_00001-of-00010.bin:  98% 1.51G/1.54G [00:04<00:00, 159MB/s]
# Downloading (…)l_00001-of-00010.bin: 100% 1.54G/1.54G [00:05<00:00, 303MB/s]
# Downloading shards:   9% 1/11 [00:05<00:52,  5.21s/it]
# Downloading (…)l_00002-of-00010.bin:   0% 0.00/1.43G [00:00<?, ?B/s]
# Downloading (…)l_00002-of-00010.bin:   2% 31.5M/1.43G [00:00<00:04, 279MB/s]
# Downloading (…)l_00002-of-00010.bin:   4% 62.9M/1.43G [00:00<00:04, 293MB/s]
# Downloading (…)l_00002-of-00010.bin:   7% 105M/1.43G [00:00<00:03, 347MB/s]
# Downloading (…)l_00002-of-00010.bin:  11% 157M/1.43G [00:00<00:03, 395MB/s]
# Downloading (…)l_00002-of-00010.bin:  15% 210M/1.43G [00:00<00:02, 422MB/s]
# Downloading (…)l_00002-of-00010.bin:  18% 262M/1.43G [00:00<00:02, 395MB/s]
# Downloading (…)l_00002-of-00010.bin:  21% 304M/1.43G [00:00<00:02, 400MB/s]
# Downloading (…)l_00002-of-00010.bin:  24% 346M/1.43G [00:00<00:02, 392MB/s]
# Downloading (…)l_00002-of-00010.bin:  27% 388M/1.43G [00:01<00:03, 310MB/s]
# Downloading (…)l_00002-of-00010.bin:  30% 430M/1.43G [00:01<00:03, 289MB/s]
# Downloading (…)l_00002-of-00010.bin:  34% 482M/1.43G [00:01<00:02, 327MB/s]
# Downloading (…)l_00002-of-00010.bin:  37% 535M/1.43G [00:01<00:02, 362MB/s]
# Downloading (…)l_00002-of-00010.bin:  41% 587M/1.43G [00:01<00:02, 386MB/s]
# Downloading (…)l_00002-of-00010.bin:  45% 640M/1.43G [00:01<00:01, 404MB/s]
# Downloading (…)l_00002-of-00010.bin:  49% 692M/1.43G [00:01<00:01, 414MB/s]
# Downloading (…)l_00002-of-00010.bin:  52% 744M/1.43G [00:01<00:01, 422MB/s]
# Downloading (…)l_00002-of-00010.bin:  56% 797M/1.43G [00:02<00:01, 423MB/s]
# Downloading (…)l_00002-of-00010.bin:  60% 849M/1.43G [00:02<00:01, 423MB/s]
# Downloading (…)l_00002-of-00010.bin:  63% 902M/1.43G [00:02<00:01, 423MB/s]
# Downloading (…)l_00002-of-00010.bin:  67% 954M/1.43G [00:02<00:01, 423MB/s]
# Downloading (…)l_00002-of-00010.bin:  71% 1.01G/1.43G [00:02<00:00, 420MB/s]
# Downloading (…)l_00002-of-00010.bin:  74% 1.06G/1.43G [00:02<00:00, 418MB/s]
# Downloading (…)l_00002-of-00010.bin:  78% 1.11G/1.43G [00:02<00:00, 420MB/s]
# Downloading (…)l_00002-of-00010.bin:  82% 1.16G/1.43G [00:02<00:00, 427MB/s]
# Downloading (…)l_00002-of-00010.bin:  85% 1.22G/1.43G [00:03<00:00, 444MB/s]
# Downloading (…)l_00002-of-00010.bin:  89% 1.27G/1.43G [00:03<00:00, 456MB/s]
# Downloading (…)l_00002-of-00010.bin:  93% 1.32G/1.43G [00:03<00:00, 463MB/s]
# Downloading (…)l_00002-of-00010.bin:  96% 1.37G/1.43G [00:03<00:00, 469MB/s]
# Downloading (…)l_00002-of-00010.bin: 100% 1.43G/1.43G [00:03<00:00, 402MB/s]
# Downloading shards:  18% 2/11 [00:08<00:38,  4.30s/it]
# Downloading (…)l_00003-of-00010.bin:   0% 0.00/1.31G [00:00<?, ?B/s]
# Downloading (…)l_00003-of-00010.bin:   4% 52.4M/1.31G [00:00<00:02, 457MB/s]
# Downloading (…)l_00003-of-00010.bin:   8% 105M/1.31G [00:00<00:04, 283MB/s]
# Downloading (…)l_00003-of-00010.bin:  11% 147M/1.31G [00:00<00:04, 250MB/s]
# Downloading (…)l_00003-of-00010.bin:  14% 178M/1.31G [00:00<00:04, 231MB/s]
# Downloading (…)l_00003-of-00010.bin:  16% 210M/1.31G [00:00<00:04, 224MB/s]
# Downloading (…)l_00003-of-00010.bin:  18% 241M/1.31G [00:01<00:04, 214MB/s]
# Downloading (…)l_00003-of-00010.bin:  21% 273M/1.31G [00:01<00:04, 211MB/s]
# Downloading (…)l_00003-of-00010.bin:  23% 304M/1.31G [00:01<00:04, 221MB/s]
# Downloading (…)l_00003-of-00010.bin:  26% 336M/1.31G [00:01<00:04, 234MB/s]
# Downloading (…)l_00003-of-00010.bin:  28% 367M/1.31G [00:01<00:03, 236MB/s]
# Downloading (…)l_00003-of-00010.bin:  30% 398M/1.31G [00:01<00:03, 253MB/s]
# Downloading (…)l_00003-of-00010.bin:  34% 440M/1.31G [00:01<00:03, 268MB/s]
# Downloading (…)l_00003-of-00010.bin:  37% 482M/1.31G [00:01<00:02, 284MB/s]
# Downloading (…)l_00003-of-00010.bin:  40% 524M/1.31G [00:02<00:02, 307MB/s]
# Downloading (…)l_00003-of-00010.bin:  43% 566M/1.31G [00:02<00:02, 308MB/s]
# Downloading (…)l_00003-of-00010.bin:  46% 608M/1.31G [00:02<00:02, 334MB/s]
# Downloading (…)l_00003-of-00010.bin:  50% 661M/1.31G [00:02<00:01, 365MB/s]
# Downloading (…)l_00003-of-00010.bin:  54% 713M/1.31G [00:02<00:01, 389MB/s]
# Downloading (…)l_00003-of-00010.bin:  58% 765M/1.31G [00:02<00:01, 401MB/s]
# Downloading (…)l_00003-of-00010.bin:  62% 807M/1.31G [00:02<00:01, 406MB/s]
# Downloading (…)l_00003-of-00010.bin:  65% 849M/1.31G [00:02<00:01, 407MB/s]
# Downloading (…)l_00003-of-00010.bin:  69% 902M/1.31G [00:02<00:00, 413MB/s]
# Downloading (…)l_00003-of-00010.bin:  73% 954M/1.31G [00:03<00:00, 420MB/s]
# Downloading (…)l_00003-of-00010.bin:  77% 1.01G/1.31G [00:03<00:00, 423MB/s]
# Downloading (…)l_00003-of-00010.bin:  81% 1.06G/1.31G [00:03<00:00, 425MB/s]
# Downloading (…)l_00003-of-00010.bin:  85% 1.11G/1.31G [00:03<00:00, 425MB/s]
# Downloading (…)l_00003-of-00010.bin:  89% 1.16G/1.31G [00:03<00:00, 419MB/s]
# Downloading (…)l_00003-of-00010.bin:  93% 1.22G/1.31G [00:03<00:00, 421MB/s]
# Downloading (…)l_00003-of-00010.bin: 100% 1.31G/1.31G [00:03<00:00, 332MB/s]
# Downloading shards:  27% 3/11 [00:12<00:33,  4.19s/it]
# Downloading (…)l_00004-of-00010.bin:   0% 0.00/1.83G [00:00<?, ?B/s]
# Downloading (…)l_00004-of-00010.bin:   3% 52.4M/1.83G [00:00<00:04, 423MB/s]
# Downloading (…)l_00004-of-00010.bin:   6% 105M/1.83G [00:00<00:03, 433MB/s]
# Downloading (…)l_00004-of-00010.bin:   9% 157M/1.83G [00:00<00:03, 443MB/s]
# Downloading (…)l_00004-of-00010.bin:  11% 210M/1.83G [00:00<00:03, 446MB/s]
# Downloading (…)l_00004-of-00010.bin:  14% 262M/1.83G [00:00<00:03, 445MB/s]
# Downloading (…)l_00004-of-00010.bin:  17% 315M/1.83G [00:00<00:03, 449MB/s]
# Downloading (…)l_00004-of-00010.bin:  20% 367M/1.83G [00:00<00:03, 455MB/s]
# Downloading (…)l_00004-of-00010.bin:  23% 419M/1.83G [00:00<00:03, 462MB/s]
# Downloading (…)l_00004-of-00010.bin:  26% 472M/1.83G [00:01<00:02, 461MB/s]
# Downloading (…)l_00004-of-00010.bin:  29% 524M/1.83G [00:01<00:02, 461MB/s]
# Downloading (…)l_00004-of-00010.bin:  31% 577M/1.83G [00:01<00:02, 456MB/s]
# Downloading (…)l_00004-of-00010.bin:  34% 629M/1.83G [00:01<00:03, 309MB/s]
# Downloading (…)l_00004-of-00010.bin:  37% 671M/1.83G [00:01<00:04, 280MB/s]
# Downloading (…)l_00004-of-00010.bin:  39% 713M/1.83G [00:01<00:04, 255MB/s]
# Downloading (…)l_00004-of-00010.bin:  41% 744M/1.83G [00:02<00:04, 247MB/s]
# Downloading (…)l_00004-of-00010.bin:  42% 776M/1.83G [00:02<00:04, 229MB/s]
# Downloading (…)l_00004-of-00010.bin:  44% 807M/1.83G [00:02<00:06, 168MB/s]
# Downloading (…)l_00004-of-00010.bin:  47% 860M/1.83G [00:02<00:04, 223MB/s]
# Downloading (…)l_00004-of-00010.bin:  50% 912M/1.83G [00:02<00:03, 270MB/s]
# Downloading (…)l_00004-of-00010.bin:  52% 954M/1.83G [00:03<00:03, 261MB/s]
# Downloading (…)l_00004-of-00010.bin:  54% 996M/1.83G [00:03<00:03, 277MB/s]
# Downloading (…)l_00004-of-00010.bin:  57% 1.05G/1.83G [00:03<00:02, 318MB/s]
# Downloading (…)l_00004-of-00010.bin:  60% 1.10G/1.83G [00:03<00:02, 352MB/s]
# Downloading (…)l_00004-of-00010.bin:  62% 1.14G/1.83G [00:03<00:01, 366MB/s]
# Downloading (…)l_00004-of-00010.bin:  65% 1.20G/1.83G [00:03<00:01, 390MB/s]
# Downloading (…)l_00004-of-00010.bin:  68% 1.25G/1.83G [00:03<00:01, 401MB/s]
# Downloading (…)l_00004-of-00010.bin:  71% 1.30G/1.83G [00:03<00:01, 413MB/s]
# Downloading (…)l_00004-of-00010.bin:  74% 1.35G/1.83G [00:03<00:01, 423MB/s]
# Downloading (…)l_00004-of-00010.bin:  77% 1.41G/1.83G [00:04<00:01, 428MB/s]
# Downloading (…)l_00004-of-00010.bin:  80% 1.46G/1.83G [00:04<00:00, 430MB/s]
# Downloading (…)l_00004-of-00010.bin:  82% 1.51G/1.83G [00:04<00:00, 424MB/s]
# Downloading (…)l_00004-of-00010.bin:  85% 1.56G/1.83G [00:04<00:00, 428MB/s]
# Downloading (…)l_00004-of-00010.bin:  88% 1.61G/1.83G [00:04<00:00, 427MB/s]
# Downloading (…)l_00004-of-00010.bin:  91% 1.67G/1.83G [00:04<00:00, 428MB/s]
# Downloading (…)l_00004-of-00010.bin:  94% 1.72G/1.83G [00:04<00:00, 429MB/s]
# Downloading (…)l_00004-of-00010.bin:  97% 1.77G/1.83G [00:04<00:00, 429MB/s]
# Downloading (…)l_00004-of-00010.bin: 100% 1.83G/1.83G [00:05<00:00, 361MB/s]
# Downloading shards:  36% 4/11 [00:18<00:32,  4.59s/it]
# Downloading (…)l_00005-of-00010.bin:   0% 0.00/1.35G [00:00<?, ?B/s]
# Downloading (…)l_00005-of-00010.bin:   4% 52.4M/1.35G [00:00<00:02, 469MB/s]
# Downloading (…)l_00005-of-00010.bin:   8% 105M/1.35G [00:00<00:02, 485MB/s]
# Downloading (…)l_00005-of-00010.bin:  12% 157M/1.35G [00:00<00:02, 489MB/s]
# Downloading (…)l_00005-of-00010.bin:  16% 210M/1.35G [00:00<00:02, 496MB/s]
# Downloading (…)l_00005-of-00010.bin:  19% 262M/1.35G [00:00<00:03, 292MB/s]
# Downloading (…)l_00005-of-00010.bin:  23% 304M/1.35G [00:00<00:03, 281MB/s]
# Downloading (…)l_00005-of-00010.bin:  26% 346M/1.35G [00:01<00:03, 277MB/s]
# Downloading (…)l_00005-of-00010.bin:  28% 377M/1.35G [00:01<00:03, 274MB/s]
# Downloading (…)l_00005-of-00010.bin:  30% 409M/1.35G [00:01<00:03, 277MB/s]
# Downloading (…)l_00005-of-00010.bin:  33% 440M/1.35G [00:01<00:03, 271MB/s]
# Downloading (…)l_00005-of-00010.bin:  35% 472M/1.35G [00:01<00:03, 272MB/s]
# Downloading (…)l_00005-of-00010.bin:  37% 503M/1.35G [00:01<00:03, 265MB/s]
# Downloading (…)l_00005-of-00010.bin:  40% 535M/1.35G [00:01<00:03, 266MB/s]
# Downloading (…)l_00005-of-00010.bin:  42% 566M/1.35G [00:01<00:03, 256MB/s]
# Downloading (…)l_00005-of-00010.bin:  44% 598M/1.35G [00:02<00:02, 256MB/s]
# Downloading (…)l_00005-of-00010.bin:  47% 629M/1.35G [00:02<00:02, 244MB/s]
# Downloading (…)l_00005-of-00010.bin:  49% 661M/1.35G [00:02<00:02, 238MB/s]
# Downloading (…)l_00005-of-00010.bin:  51% 692M/1.35G [00:02<00:02, 243MB/s]
# Downloading (…)l_00005-of-00010.bin:  54% 724M/1.35G [00:02<00:02, 244MB/s]
# Downloading (…)l_00005-of-00010.bin:  56% 755M/1.35G [00:02<00:02, 253MB/s]
# Downloading (…)l_00005-of-00010.bin:  58% 786M/1.35G [00:02<00:02, 255MB/s]
# Downloading (…)l_00005-of-00010.bin:  61% 818M/1.35G [00:02<00:01, 270MB/s]
# Downloading (…)l_00005-of-00010.bin:  63% 849M/1.35G [00:03<00:01, 261MB/s]
# Downloading (…)l_00005-of-00010.bin:  66% 891M/1.35G [00:03<00:01, 288MB/s]
# Downloading (…)l_00005-of-00010.bin:  69% 933M/1.35G [00:03<00:01, 322MB/s]
# Downloading (…)l_00005-of-00010.bin:  73% 986M/1.35G [00:03<00:01, 360MB/s]
# Downloading (…)l_00005-of-00010.bin:  77% 1.04G/1.35G [00:03<00:00, 389MB/s]
# Downloading (…)l_00005-of-00010.bin:  81% 1.09G/1.35G [00:03<00:00, 409MB/s]
# Downloading (…)l_00005-of-00010.bin:  84% 1.13G/1.35G [00:03<00:00, 386MB/s]
# Downloading (…)l_00005-of-00010.bin:  88% 1.18G/1.35G [00:03<00:00, 398MB/s]
# Downloading (…)l_00005-of-00010.bin:  92% 1.24G/1.35G [00:03<00:00, 408MB/s]
# Downloading (…)l_00005-of-00010.bin:  95% 1.29G/1.35G [00:04<00:00, 415MB/s]
# Downloading (…)l_00005-of-00010.bin: 100% 1.35G/1.35G [00:04<00:00, 319MB/s]
# Downloading shards:  45% 5/11 [00:22<00:26,  4.50s/it]
# Downloading (…)l_00006-of-00010.bin:   0% 0.00/1.35G [00:00<?, ?B/s]
# Downloading (…)l_00006-of-00010.bin:   4% 52.4M/1.35G [00:00<00:02, 466MB/s]
# Downloading (…)l_00006-of-00010.bin:   8% 105M/1.35G [00:00<00:02, 474MB/s]
# Downloading (…)l_00006-of-00010.bin:  12% 157M/1.35G [00:00<00:02, 478MB/s]
# Downloading (…)l_00006-of-00010.bin:  16% 210M/1.35G [00:00<00:02, 476MB/s]
# Downloading (…)l_00006-of-00010.bin:  19% 262M/1.35G [00:00<00:02, 476MB/s]
# Downloading (…)l_00006-of-00010.bin:  23% 315M/1.35G [00:00<00:02, 475MB/s]
# Downloading (…)l_00006-of-00010.bin:  27% 367M/1.35G [00:00<00:02, 407MB/s]
# Downloading (…)l_00006-of-00010.bin:  31% 419M/1.35G [00:01<00:02, 364MB/s]
# Downloading (…)l_00006-of-00010.bin:  34% 461M/1.35G [00:01<00:02, 335MB/s]
# Downloading (…)l_00006-of-00010.bin:  37% 503M/1.35G [00:01<00:02, 317MB/s]
# Downloading (…)l_00006-of-00010.bin:  40% 545M/1.35G [00:01<00:02, 300MB/s]
# Downloading (…)l_00006-of-00010.bin:  43% 577M/1.35G [00:01<00:02, 283MB/s]
# Downloading (…)l_00006-of-00010.bin:  45% 608M/1.35G [00:01<00:02, 277MB/s]
# Downloading (…)l_00006-of-00010.bin:  47% 640M/1.35G [00:01<00:02, 266MB/s]
# Downloading (…)l_00006-of-00010.bin:  50% 671M/1.35G [00:01<00:02, 256MB/s]
# Downloading (…)l_00006-of-00010.bin:  52% 703M/1.35G [00:02<00:02, 253MB/s]
# Downloading (…)l_00006-of-00010.bin:  54% 734M/1.35G [00:02<00:02, 248MB/s]
# Downloading (…)l_00006-of-00010.bin:  57% 765M/1.35G [00:02<00:02, 244MB/s]
# Downloading (…)l_00006-of-00010.bin:  59% 797M/1.35G [00:02<00:02, 251MB/s]
# Downloading (…)l_00006-of-00010.bin:  61% 828M/1.35G [00:02<00:02, 255MB/s]
# Downloading (…)l_00006-of-00010.bin:  64% 860M/1.35G [00:02<00:01, 269MB/s]
# Downloading (…)l_00006-of-00010.bin:  67% 902M/1.35G [00:02<00:01, 301MB/s]
# Downloading (…)l_00006-of-00010.bin:  70% 944M/1.35G [00:02<00:01, 331MB/s]
# Downloading (…)l_00006-of-00010.bin:  74% 996M/1.35G [00:03<00:00, 368MB/s]
# Downloading (…)l_00006-of-00010.bin:  78% 1.05G/1.35G [00:03<00:00, 392MB/s]
# Downloading (…)l_00006-of-00010.bin:  82% 1.10G/1.35G [00:03<00:00, 409MB/s]
# Downloading (…)l_00006-of-00010.bin:  85% 1.14G/1.35G [00:03<00:00, 410MB/s]
# Downloading (…)l_00006-of-00010.bin:  89% 1.20G/1.35G [00:03<00:00, 416MB/s]
# Downloading (…)l_00006-of-00010.bin:  92% 1.25G/1.35G [00:03<00:00, 425MB/s]
# Downloading (…)l_00006-of-00010.bin:  96% 1.30G/1.35G [00:03<00:00, 412MB/s]
# Downloading (…)l_00006-of-00010.bin: 100% 1.35G/1.35G [00:03<00:00, 347MB/s]
# Downloading shards:  55% 6/11 [00:26<00:21,  4.34s/it]
# Downloading (…)l_00007-of-00010.bin:   0% 0.00/1.54G [00:00<?, ?B/s]
# Downloading (…)l_00007-of-00010.bin:   2% 31.5M/1.54G [00:00<00:04, 304MB/s]
# Downloading (…)l_00007-of-00010.bin:   4% 62.9M/1.54G [00:00<00:04, 306MB/s]
# Downloading (…)l_00007-of-00010.bin:   7% 105M/1.54G [00:00<00:04, 337MB/s]
# Downloading (…)l_00007-of-00010.bin:  10% 157M/1.54G [00:00<00:03, 377MB/s]
# Downloading (…)l_00007-of-00010.bin:  14% 210M/1.54G [00:00<00:03, 405MB/s]
# Downloading (…)l_00007-of-00010.bin:  17% 262M/1.54G [00:00<00:03, 408MB/s]
# Downloading (…)l_00007-of-00010.bin:  20% 304M/1.54G [00:00<00:03, 410MB/s]
# Downloading (…)l_00007-of-00010.bin:  22% 346M/1.54G [00:00<00:02, 409MB/s]
# Downloading (…)l_00007-of-00010.bin:  25% 388M/1.54G [00:00<00:02, 411MB/s]
# Downloading (…)l_00007-of-00010.bin:  28% 430M/1.54G [00:01<00:02, 411MB/s]
# Downloading (…)l_00007-of-00010.bin:  31% 482M/1.54G [00:01<00:02, 420MB/s]
# Downloading (…)l_00007-of-00010.bin:  35% 535M/1.54G [00:01<00:02, 426MB/s]
# Downloading (…)l_00007-of-00010.bin:  38% 587M/1.54G [00:01<00:02, 428MB/s]
# Downloading (…)l_00007-of-00010.bin:  41% 640M/1.54G [00:01<00:02, 421MB/s]
# Downloading (…)l_00007-of-00010.bin:  45% 692M/1.54G [00:01<00:01, 429MB/s]
# Downloading (…)l_00007-of-00010.bin:  48% 744M/1.54G [00:01<00:01, 438MB/s]
# Downloading (…)l_00007-of-00010.bin:  52% 797M/1.54G [00:01<00:01, 449MB/s]
# Downloading (…)l_00007-of-00010.bin:  55% 849M/1.54G [00:02<00:02, 344MB/s]
# Downloading (…)l_00007-of-00010.bin:  58% 891M/1.54G [00:02<00:01, 337MB/s]
# Downloading (…)l_00007-of-00010.bin:  60% 933M/1.54G [00:02<00:01, 318MB/s]
# Downloading (…)l_00007-of-00010.bin:  63% 975M/1.54G [00:02<00:01, 306MB/s]
# Downloading (…)l_00007-of-00010.bin:  66% 1.02G/1.54G [00:02<00:01, 302MB/s]
# Downloading (…)l_00007-of-00010.bin:  68% 1.05G/1.54G [00:02<00:01, 302MB/s]
# Downloading (…)l_00007-of-00010.bin:  70% 1.08G/1.54G [00:02<00:01, 299MB/s]
# Downloading (…)l_00007-of-00010.bin:  72% 1.11G/1.54G [00:03<00:01, 296MB/s]
# Downloading (…)l_00007-of-00010.bin:  74% 1.14G/1.54G [00:03<00:01, 293MB/s]
# Downloading (…)l_00007-of-00010.bin:  76% 1.17G/1.54G [00:03<00:01, 291MB/s]
# Downloading (…)l_00007-of-00010.bin:  78% 1.21G/1.54G [00:03<00:01, 287MB/s]
# Downloading (…)l_00007-of-00010.bin:  80% 1.24G/1.54G [00:03<00:01, 278MB/s]
# Downloading (…)l_00007-of-00010.bin:  82% 1.27G/1.54G [00:03<00:01, 273MB/s]
# Downloading (…)l_00007-of-00010.bin:  84% 1.30G/1.54G [00:03<00:00, 263MB/s]
# Downloading (…)l_00007-of-00010.bin:  86% 1.33G/1.54G [00:03<00:00, 255MB/s]
# Downloading (…)l_00007-of-00010.bin:  88% 1.36G/1.54G [00:04<00:00, 242MB/s]
# Downloading (…)l_00007-of-00010.bin:  90% 1.39G/1.54G [00:04<00:00, 238MB/s]
# Downloading (…)l_00007-of-00010.bin:  92% 1.43G/1.54G [00:04<00:00, 237MB/s]
# Downloading (…)l_00007-of-00010.bin:  94% 1.46G/1.54G [00:04<00:00, 240MB/s]
# Downloading (…)l_00007-of-00010.bin:  96% 1.49G/1.54G [00:04<00:00, 245MB/s]
# Downloading (…)l_00007-of-00010.bin: 100% 1.54G/1.54G [00:04<00:00, 325MB/s]
# Downloading shards:  64% 7/11 [00:31<00:18,  4.51s/it]
# Downloading (…)l_00008-of-00010.bin:   0% 0.00/1.43G [00:00<?, ?B/s]
# Downloading (…)l_00008-of-00010.bin:   4% 52.4M/1.43G [00:00<00:03, 436MB/s]
# Downloading (…)l_00008-of-00010.bin:   7% 105M/1.43G [00:00<00:03, 437MB/s]
# Downloading (…)l_00008-of-00010.bin:  11% 157M/1.43G [00:00<00:02, 436MB/s]
# Downloading (…)l_00008-of-00010.bin:  15% 210M/1.43G [00:00<00:02, 434MB/s]
# Downloading (…)l_00008-of-00010.bin:  18% 262M/1.43G [00:00<00:02, 429MB/s]
# Downloading (…)l_00008-of-00010.bin:  22% 315M/1.43G [00:00<00:02, 438MB/s]
# Downloading (…)l_00008-of-00010.bin:  26% 367M/1.43G [00:00<00:02, 445MB/s]
# Downloading (…)l_00008-of-00010.bin:  29% 419M/1.43G [00:00<00:02, 437MB/s]
# Downloading (…)l_00008-of-00010.bin:  33% 472M/1.43G [00:01<00:02, 438MB/s]
# Downloading (…)l_00008-of-00010.bin:  37% 524M/1.43G [00:01<00:02, 438MB/s]
# Downloading (…)l_00008-of-00010.bin:  40% 577M/1.43G [00:01<00:02, 416MB/s]
# Downloading (…)l_00008-of-00010.bin:  43% 619M/1.43G [00:01<00:01, 411MB/s]
# Downloading (…)l_00008-of-00010.bin:  47% 671M/1.43G [00:01<00:01, 422MB/s]
# Downloading (…)l_00008-of-00010.bin:  51% 724M/1.43G [00:01<00:01, 425MB/s]
# Downloading (…)l_00008-of-00010.bin:  54% 776M/1.43G [00:01<00:01, 427MB/s]
# Downloading (…)l_00008-of-00010.bin:  58% 828M/1.43G [00:01<00:01, 443MB/s]
# Downloading (…)l_00008-of-00010.bin:  62% 881M/1.43G [00:02<00:01, 451MB/s]
# Downloading (…)l_00008-of-00010.bin:  65% 933M/1.43G [00:02<00:01, 456MB/s]
# Downloading (…)l_00008-of-00010.bin:  69% 986M/1.43G [00:02<00:00, 459MB/s]
# Downloading (…)l_00008-of-00010.bin:  73% 1.04G/1.43G [00:02<00:00, 461MB/s]
# Downloading (…)l_00008-of-00010.bin:  76% 1.09G/1.43G [00:02<00:01, 281MB/s]
# Downloading (…)l_00008-of-00010.bin:  79% 1.13G/1.43G [00:02<00:01, 288MB/s]
# Downloading (…)l_00008-of-00010.bin:  82% 1.17G/1.43G [00:02<00:00, 291MB/s]
# Downloading (…)l_00008-of-00010.bin:  85% 1.22G/1.43G [00:03<00:00, 289MB/s]
# Downloading (…)l_00008-of-00010.bin:  88% 1.26G/1.43G [00:03<00:00, 291MB/s]
# Downloading (…)l_00008-of-00010.bin:  90% 1.29G/1.43G [00:03<00:00, 290MB/s]
# Downloading (…)l_00008-of-00010.bin:  93% 1.32G/1.43G [00:03<00:00, 282MB/s]
# Downloading (…)l_00008-of-00010.bin:  95% 1.35G/1.43G [00:03<00:00, 275MB/s]
# Downloading (…)l_00008-of-00010.bin:  97% 1.38G/1.43G [00:03<00:00, 270MB/s]
# Downloading (…)l_00008-of-00010.bin: 100% 1.43G/1.43G [00:03<00:00, 360MB/s]
# Downloading shards:  73% 8/11 [00:35<00:13,  4.37s/it]
# Downloading (…)l_00009-of-00010.bin:   0% 0.00/1.34G [00:00<?, ?B/s]
# Downloading (…)l_00009-of-00010.bin:   2% 31.5M/1.34G [00:00<00:05, 253MB/s]
# Downloading (…)l_00009-of-00010.bin:   5% 62.9M/1.34G [00:00<00:04, 277MB/s]
# Downloading (…)l_00009-of-00010.bin:   8% 105M/1.34G [00:00<00:03, 318MB/s]
# Downloading (…)l_00009-of-00010.bin:  11% 147M/1.34G [00:00<00:03, 343MB/s]
# Downloading (…)l_00009-of-00010.bin:  14% 189M/1.34G [00:00<00:03, 365MB/s]
# Downloading (…)l_00009-of-00010.bin:  18% 241M/1.34G [00:00<00:02, 393MB/s]
# Downloading (…)l_00009-of-00010.bin:  22% 294M/1.34G [00:00<00:02, 410MB/s]
# Downloading (…)l_00009-of-00010.bin:  26% 346M/1.34G [00:00<00:02, 419MB/s]
# Downloading (…)l_00009-of-00010.bin:  29% 388M/1.34G [00:01<00:03, 267MB/s]
# Downloading (…)l_00009-of-00010.bin:  32% 430M/1.34G [00:01<00:03, 286MB/s]
# Downloading (…)l_00009-of-00010.bin:  35% 472M/1.34G [00:01<00:02, 307MB/s]
# Downloading (…)l_00009-of-00010.bin:  38% 514M/1.34G [00:01<00:02, 330MB/s]
# Downloading (…)l_00009-of-00010.bin:  41% 556M/1.34G [00:01<00:02, 332MB/s]
# Downloading (…)l_00009-of-00010.bin:  45% 598M/1.34G [00:01<00:02, 334MB/s]
# Downloading (…)l_00009-of-00010.bin:  48% 640M/1.34G [00:01<00:02, 336MB/s]
# Downloading (…)l_00009-of-00010.bin:  51% 682M/1.34G [00:02<00:01, 344MB/s]
# Downloading (…)l_00009-of-00010.bin:  54% 724M/1.34G [00:02<00:01, 352MB/s]
# Downloading (…)l_00009-of-00010.bin:  57% 765M/1.34G [00:02<00:01, 355MB/s]
# Downloading (…)l_00009-of-00010.bin:  60% 807M/1.34G [00:02<00:01, 349MB/s]
# Downloading (…)l_00009-of-00010.bin:  63% 849M/1.34G [00:02<00:01, 344MB/s]
# Downloading (…)l_00009-of-00010.bin:  66% 891M/1.34G [00:02<00:01, 353MB/s]
# Downloading (…)l_00009-of-00010.bin:  70% 944M/1.34G [00:02<00:01, 388MB/s]
# Downloading (…)l_00009-of-00010.bin:  74% 996M/1.34G [00:02<00:00, 412MB/s]
# Downloading (…)l_00009-of-00010.bin:  78% 1.05G/1.34G [00:02<00:00, 430MB/s]
# Downloading (…)l_00009-of-00010.bin:  82% 1.10G/1.34G [00:03<00:00, 442MB/s]
# Downloading (…)l_00009-of-00010.bin:  86% 1.15G/1.34G [00:03<00:00, 451MB/s]
# Downloading (…)l_00009-of-00010.bin:  90% 1.21G/1.34G [00:03<00:00, 455MB/s]
# Downloading (…)l_00009-of-00010.bin:  94% 1.26G/1.34G [00:03<00:00, 458MB/s]
# Downloading (…)l_00009-of-00010.bin: 100% 1.34G/1.34G [00:03<00:00, 370MB/s]
# Downloading shards:  82% 9/11 [00:39<00:08,  4.21s/it]
# Downloading (…)l_00010-of-00010.bin:   0% 0.00/1.33G [00:00<?, ?B/s]
# Downloading (…)l_00010-of-00010.bin:   4% 52.4M/1.33G [00:00<00:02, 486MB/s]
# Downloading (…)l_00010-of-00010.bin:   8% 105M/1.33G [00:00<00:02, 458MB/s]
# Downloading (…)l_00010-of-00010.bin:  12% 157M/1.33G [00:00<00:03, 347MB/s]
# Downloading (…)l_00010-of-00010.bin:  15% 199M/1.33G [00:00<00:03, 309MB/s]
# Downloading (…)l_00010-of-00010.bin:  18% 241M/1.33G [00:00<00:03, 286MB/s]
# Downloading (…)l_00010-of-00010.bin:  21% 273M/1.33G [00:00<00:03, 277MB/s]
# Downloading (…)l_00010-of-00010.bin:  23% 304M/1.33G [00:01<00:03, 272MB/s]
# Downloading (…)l_00010-of-00010.bin:  25% 336M/1.33G [00:01<00:03, 271MB/s]
# Downloading (…)l_00010-of-00010.bin:  28% 367M/1.33G [00:01<00:03, 275MB/s]
# Downloading (…)l_00010-of-00010.bin:  31% 409M/1.33G [00:01<00:03, 290MB/s]
# Downloading (…)l_00010-of-00010.bin:  34% 451M/1.33G [00:01<00:02, 317MB/s]
# Downloading (…)l_00010-of-00010.bin:  38% 503M/1.33G [00:01<00:02, 356MB/s]
# Downloading (…)l_00010-of-00010.bin:  41% 545M/1.33G [00:01<00:02, 372MB/s]
# Downloading (…)l_00010-of-00010.bin:  45% 598M/1.33G [00:01<00:01, 392MB/s]
# Downloading (…)l_00010-of-00010.bin:  48% 640M/1.33G [00:01<00:01, 392MB/s]
# Downloading (…)l_00010-of-00010.bin:  51% 682M/1.33G [00:02<00:01, 395MB/s]
# Downloading (…)l_00010-of-00010.bin:  55% 734M/1.33G [00:02<00:01, 402MB/s]
# Downloading (…)l_00010-of-00010.bin:  59% 776M/1.33G [00:02<00:01, 406MB/s]
# Downloading (…)l_00010-of-00010.bin:  62% 828M/1.33G [00:02<00:01, 414MB/s]
# Downloading (…)l_00010-of-00010.bin:  66% 881M/1.33G [00:02<00:01, 421MB/s]
# Downloading (…)l_00010-of-00010.bin:  70% 933M/1.33G [00:02<00:00, 422MB/s]
# Downloading (…)l_00010-of-00010.bin:  74% 986M/1.33G [00:02<00:00, 416MB/s]
# Downloading (…)l_00010-of-00010.bin:  78% 1.03G/1.33G [00:02<00:00, 414MB/s]
# Downloading (…)l_00010-of-00010.bin:  81% 1.07G/1.33G [00:02<00:00, 415MB/s]
# Downloading (…)l_00010-of-00010.bin:  84% 1.11G/1.33G [00:03<00:00, 407MB/s]
# Downloading (…)l_00010-of-00010.bin:  87% 1.15G/1.33G [00:03<00:00, 410MB/s]
# Downloading (…)l_00010-of-00010.bin:  90% 1.20G/1.33G [00:03<00:00, 411MB/s]
# Downloading (…)l_00010-of-00010.bin:  93% 1.24G/1.33G [00:03<00:00, 410MB/s]
# Downloading (…)l_00010-of-00010.bin:  97% 1.28G/1.33G [00:03<00:00, 410MB/s]
# Downloading (…)l_00010-of-00010.bin: 100% 1.33G/1.33G [00:03<00:00, 367MB/s]
# Downloading shards:  91% 10/11 [00:43<00:04,  4.06s/it]
# Downloading (…)l_00011-of-00010.bin: 100% 33.6M/33.6M [00:00<00:00, 372MB/s]
# Downloading shards: 100% 11/11 [00:43<00:00,  3.93s/it]
# Loading checkpoint shards: 100% 11/11 [00:25<00:00,  2.30s/it]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)neration_config.json: 100% 116/116 [00:00<00:00, 591kB/s]
# > INFO    Using block size 1024
# > INFO    creating trainer
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:214: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
#   0% 0/30 [00:00<?, ?it/s]You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.6708, 'learning_rate': 6.666666666666667e-05, 'epoch': 0.1}
#   3% 1/30 [00:07<03:43,  7.69s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.6708, 'learning_rate': 0.00013333333333333334, 'epoch': 1.1}
#   7% 2/30 [00:12<02:50,  6.09s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.6185, 'learning_rate': 0.0002, 'epoch': 2.1}
# {'train_runtime': 17.8992, 'train_samples_per_second': 19.61, 'train_steps_per_second': 1.676, 'train_loss': 1.6533660093943279, 'epoch': 2.1}
#  10% 3/30 [00:17<02:41,  5.97s/it]
# > INFO    Finished training, saving model...
# > INFO    Pushing model to hub...
# adapter_model.bin:   0% 0.00/27.3M [00:00<?, ?B/s]
# adapter_model.bin:   0% 0.00/27.3M [00:00<?, ?B/s]
#
# rng_state.pth:   0% 0.00/14.2k [00:00<?, ?B/s]
#
#
# scheduler.pt:   0% 0.00/1.06k [00:00<?, ?B/s]
#
#
#
# Upload 9 LFS files:   0% 0/9 [00:00<?, ?it/s]
#
#
#
#
# optimizer.pt:   0% 0.00/54.6M [00:00<?, ?B/s]
#
#
# scheduler.pt: 100% 1.06k/1.06k [00:00<00:00, 4.57kB/s]
# adapter_model.bin:   0% 16.4k/27.3M [00:00<07:00, 64.9kB/s]
#
# adapter_model.bin:   0% 16.4k/27.3M [00:00<07:28, 60.8kB/s]
#
#
#
#
# optimizer.pt:   0% 16.4k/54.6M [00:00<14:35, 62.4kB/s]
# adapter_model.bin:  10% 2.65M/27.3M [00:00<00:02, 8.67MB/s]
# adapter_model.bin:  16% 4.42M/27.3M [00:00<00:02, 10.0MB/s]
#
#
#
#
# rng_state.pth: 100% 14.2k/14.2k [00:00<00:00, 23.2kB/s]
# scheduler.pt: 100% 1.06k/1.06k [00:00<00:00, 1.69kB/s]
#
# adapter_model.bin:  29% 7.85M/27.3M [00:00<00:01, 15.8MB/s]
#
#
#
#
# adapter_model.bin:  30% 8.14M/27.3M [00:00<00:01, 13.5MB/s]
#
#
#
#
# adapter_model.bin:  36% 9.83M/27.3M [00:00<00:01, 14.2MB/s]
# adapter_model.bin:  38% 10.4M/27.3M [00:00<00:01, 13.2MB/s]
#
#
#
#
# optimizer.pt:  20% 10.9M/54.6M [00:00<00:03, 13.1MB/s]
#
# adapter_model.bin:  43% 11.6M/27.3M [00:01<00:01, 13.3MB/s]
# adapter_model.bin:  57% 15.6M/27.3M [00:01<00:00, 18.4MB/s]
#
#
#
#
# optimizer.pt:  27% 14.5M/54.6M [00:01<00:02, 15.8MB/s]
#
#
# training_args.bin:   0% 0.00/4.54k [00:00<?, ?B/s]
# training_args.bin: 100% 4.54k/4.54k [00:00<00:00, 11.6kB/s]
#
#
#
#
#
# optimizer.pt:  30% 16.2M/54.6M [00:01<00:04, 8.57MB/s]
#
#
# tokenizer.model:   0% 0.00/493k [00:00<?, ?B/s]
#
#
#
#
# tokenizer.model: 100% 493k/493k [00:00<00:00, 608kB/s]
# adapter_model.bin: 100% 27.3M/27.3M [00:01<00:00, 15.2MB/s]
#
#
#
#
#
# adapter_model.bin:  65% 17.6M/27.3M [00:02<00:01, 6.21MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 882kB/s]
#
#
#
#
#
# adapter_model.bin:  90% 24.6M/27.3M [00:02<00:00, 11.0MB/s]
#
#
#
#
# training_args.bin: 100% 4.54k/4.54k [00:00<00:00, 11.8kB/s]
# adapter_model.bin:  99% 27.0M/27.3M [00:02<00:00, 9.56MB/s]
#
#
#
#
# optimizer.pt:  59% 32.4M/54.6M [00:02<00:02, 9.40MB/s]
#
#
#
#
# optimizer.pt:  87% 47.5M/54.6M [00:03<00:00, 26.8MB/s]
#
#
#
#
# adapter_model.bin: 100% 27.3M/27.3M [00:03<00:00, 8.06MB/s]
# optimizer.pt: 100% 54.6M/54.6M [00:03<00:00, 15.2MB/s]
#
#
#
#
# Upload 9 LFS files:  11% 1/9 [00:03<00:29,  3.69s/it]
#
#
#
# Upload 9 LFS files: 100% 9/9 [00:03<00:00,  2.30it/s]

# %% [markdown]
# ## Step 5: Completed 🎉
# After the command above is completed your Model will be uploaded to Hugging Face.
#
# #### Learn more about AutoTrain (optional)
# If you want to learn more about what command-line flags are available

# %% [markdown]
# ## Step 6: Inference Engine

# %%
# !autotrain llm -h
# Out:
# /bin/bash: line 1: autotrain: command not found

# %%
# !pip install -q peft  accelerate bitsandbytes safetensors
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 121.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 28.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.1 MB/s eta 0:00:00

# %%
import torch
from peft import PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer
import transformers
adapters_name = "satvikp/mistral-7b-mj-finetuned2"
model_name = "bn22/Mistral-7B-Instruct-v0.1-sharded" #"mistralai/Mistral-7B-Instruct-v0.1"


device = "cuda" # the device to load the model onto

# %%
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    load_in_4bit=True,
    torch_dtype=torch.bfloat16,
    quantization_config=bnb_config,
    device_map='auto'
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/11 [00:00<?, ?it/s]
# Downloading (…)l_00001-of-00010.bin:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Downloading (…)l_00002-of-00010.bin:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Downloading (…)l_00003-of-00010.bin:   0%|          | 0.00/1.31G [00:00<?, ?B/s]
# Downloading (…)l_00004-of-00010.bin:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# Downloading (…)l_00005-of-00010.bin:   0%|          | 0.00/1.35G [00:00<?, ?B/s]
# Downloading (…)l_00006-of-00010.bin:   0%|          | 0.00/1.35G [00:00<?, ?B/s]
# Downloading (…)l_00007-of-00010.bin:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Downloading (…)l_00008-of-00010.bin:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Downloading (…)l_00009-of-00010.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading (…)l_00010-of-00010.bin:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading (…)l_00011-of-00010.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/11 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# ## Step 7: Peft Model Loading with upload model

# %%
model = PeftModel.from_pretrained(model, adapters_name)
# Out:
# Downloading (…)/adapter_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading adapter_model.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.bos_token_id = 1

stop_token_ids = [0]

print(f"Successfully loaded the model {model_name} into memory")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/963 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# Successfully loaded the model bn22/Mistral-7B-Instruct-v0.1-sharded into memory

# %%
text = "[INST] generate a midjourney prompt for A person walks in the rain [/INST]"

encoded = tokenizer(text, return_tensors="pt", add_special_tokens=False)
model_input = encoded
model.to(device)
generated_ids = model.generate(**model_input, max_new_tokens=200, do_sample=True)
decoded = tokenizer.batch_decode(generated_ids)
print(decoded[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1591: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# [INST] generate a midjourney prompt for A person walks in the rain [/INST] "Had she turned left instead of right, she would have missed the path that led her to a life full of wonder and excitement. But as she continued on her journey, she couldn't help but feel a sense of longing for a different path. She looked up and saw a distant figure walking through the rain, and suddenly realized that life is full of choices and each one can create a unique path. With a newfound sense of determination, she stepped forward and embraced the adventure that lay ahead. The rain that had once felt like a burden now revealed the beauty of the world around her and she was grateful for the journey that had brought her to this moment."</s>

# %%
Had she turned left instead of right, she would have missed the path that led her to a life full of wonder and excitement.
But as she continued on her journey, she couldn't help but feel a sense of longing for a different path. She looked up and saw a distant figure walking through the rain, and suddenly realized that life is full of choices and each one can create a unique path. With a newfound sense of determination, she stepped forward and embraced the adventure that lay ahead. The rain that had once felt like a burden now revealed the beauty
of the world around her and she was grateful for the journey that had brought her to this moment.
